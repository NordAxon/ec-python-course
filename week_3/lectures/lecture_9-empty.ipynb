# %% [markdown]
# # Dataframes with Pandas
#
# We will explore pandas and it's basic functionality.
# Three central concepts to pandas are:
# - series
# - dataframes
# - index

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
pd.__version__
# Out:
# '1.2.4'

# %% [markdown]
# ## pd.Series
# Is a one-dimensional data array
#
# TODO:
# 1. Create a series
# 2. Look at the attributes: values, index
# 3. Access values, single and slices
# 4. Change the index
# 5. Create series from dictionary, list, numpy array, tuple

# %%
# 1. 
apples = pd.Series([55, 22, 33, 11, 36], index=['ica', 'willys', 'coop', 'hemköp', 'livs'])
apples
# Out:
# ica       55
# willys    22
# coop      33
# hemköp    11
# livs      36
# dtype: int64

# %%
apples['willys']
# Out:
# 22

# %%
series.index
# Out:
# Index(['ica', 'willys', 'coop', 'hemköp', 'livs'], dtype='object')

# %%
d1 = {11:1, 12:2, 13:3}
pd.Series(d1)
# Out:
# 11    1
# 12    2
# 13    3
# dtype: int64

# %% [markdown]
# ### pd.DataFrame
#
# A twodimensional data matrix. A dataframe as both rows (defined by the index) and columns. Each column is a pandas series.
# To create a dataframe we need to supply data, names of columns,
#
# 1. Create a simple empty dataframe
# 2. Create a dataframe from series

# %%
df = pd.DataFrame(data=[['katt', 6, 0.3], ['hund', 20, 0.6], ['fågel', 0.2, 0.1]], 
                        index=[1,2,3], columns=['animal', 'weight','height'])

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
animal = pd.Series(['katt', 'hund', 'fågel'])
weight = pd.Series([6, 20, 0.2])

df = pd.DataFrame({'animal':animal, 'weight':weight}, index=[1,2,3])
df
# Out:
#   animal  weight
# 1   hund    20.0
# 2  fågel     0.2
# 3    NaN     NaN

# %% [markdown]
# ## pd.Index
#
# The index that represents rows in a dataframe or elements in a series. AN index is immutable - can't be changed - which makes it safer to share between series or dataframes.
#
# TODO:
# 1. Set operations as intersection, union etc

# %%
ind1 = pd.Index([1, 5, 6])
ind2 = pd.Index([1, 5, '6', 7])

ind1.symmetric_difference(ind2)
ind1.intersection(ind2)
# Out:
# Index([1, 5], dtype='object')

# %% [markdown]
# ## Load data in different formats
# - excel, csv, json

# %%
pokemon_df = pd.read_csv('Pokemon.csv')
iris_df = pd.read_json('iris.json')

# %% [markdown]
# ## Show data
#
# - Use head and tail
# - column types: dtypes
# - statistics: mean, sum, quantile -> describe

# %%
iris_df.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
pokemon_df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon_df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %%
iris_df.describe()
# Out:
#        sepalLength  sepalWidth  petalLength  petalWidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.057333     3.758000    1.199333
# std       0.828066    0.435866     1.765298    0.762238
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
pokemon_df = pokemon_df.set_index('Name')
pokemon_df.head()
# Out:
#                        # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              1  Grass  Poison    318  45      49       49       65
# Ivysaur                2  Grass  Poison    405  60      62       63       80
# Venusaur               3  Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  3  Grass  Poison    625  80     100      123      122
# Charmander             4   Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %%
pokemon_df.index
# Out:
# Index(['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur',
#        'Charmander', 'Charmeleon', 'Charizard', 'CharizardMega Charizard X',
#        'CharizardMega Charizard Y', 'Squirtle',
#        ...
#        'Noibat', 'Noivern', 'Xerneas', 'Yveltal', 'Zygarde50% Forme',
#        'Diancie', 'DiancieMega Diancie', 'HoopaHoopa Confined',
#        'HoopaHoopa Unbound', 'Volcanion'],
#       dtype='object', name='Name', length=800)

# %% [markdown]
# ## Indexing and subset
# - iloc - integer location
# - loc - location
# - by column
# - by column value
#
#
# df['col0'] returns a **column**, not a row

# %%
iris_df.loc['ica']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepalLength, Length: 150, dtype: float64

# %%
pokemon_df.loc['Bulbasaur':'Venusaur']
# Out:
#            # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur  1  Grass  Poison    318  45      49       49       65       65
# Ivysaur    2  Grass  Poison    405  60      62       63       80       80
# Venusaur   3  Grass  Poison    525  80      82       83      100      100
#
#            Speed  Generation  Legendary
# Name
# Bulbasaur     45           1      False
# Ivysaur       60           1      False
# Venusaur      80           1      False

# %% [markdown]
# ### Groupy by
# df.groupby is a very useful function when we want to perform some calculation on different groups of data

# %%
df.groupby?

# %%
pokemon_df.groupby(by=['Type 1', 'Type 2'])[['Speed', 'Attack']].mean().head(25)
# Out:
#                       Speed      Attack
# Type 1 Type 2
# Bug    Electric   86.500000   62.000000
#        Fighting   80.000000  155.000000
#        Fire       80.000000   72.500000
#        Flying     82.857143   70.142857
#        Ghost      40.000000   90.000000
#        Grass      44.500000   73.833333
#        Ground     38.000000   62.000000
#        Poison     65.916667   68.333333
#        Rock       35.000000   56.666667
#        Steel      63.428571  114.714286
#        Water      65.000000   30.000000
# Dark   Dragon     64.666667   85.000000
#        Fighting   53.000000   82.500000
#        Fire       91.666667   80.000000
#        Flying     80.200000   92.200000
#        Ghost      35.000000   80.000000
#        Ice       120.000000  107.500000
#        Psychic    59.000000   73.000000
#        Steel      65.000000  105.000000
# Dragon Electric   90.000000  150.000000
#        Fairy      80.000000  110.000000
#        Fire       90.000000  120.000000
#        Flying     98.333333  135.666667
#        Ground     82.600000  112.000000
#        Ice        95.000000  140.000000

# %% [markdown]
# ### Iteration
# Not good practise but may be necessary sometimes
# - iteration av series och dataframes
# - df.items()
# - df.iterrows()
# - never modify what you're iterating over!!!

# %%
for col in iris_df.items():
    print(col)
    break
# Out:
# ('sepalLength', 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepalLength, Length: 150, dtype: float64)

# %% [markdown]
# ### Sorting
#
# Pandas can sort in three different ways, based on:
# - column values
# - row values
# - a combination of both

# %%
pokemon_df.sort_values('HP', ascending=False)
# Out:
#              #   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Blissey    242   Normal    NaN    540  255      10       10       75      135
# Chansey    113   Normal    NaN    450  250       5        5       35      105
# Wobbuffet  202  Psychic    NaN    405  190      33       58       33       58
# Wailord    321    Water    NaN    500  170      90       45       90       45
# Alomomola  594    Water    NaN    470  165      75       80       40       45
# ...        ...      ...    ...    ...  ...     ...      ...      ...      ...
# Magikarp   129    Water    NaN    200   20      10       55       15       20
# Feebas     349    Water    NaN    200   20      15       20       10       55
# Duskull    355    Ghost    NaN    295   20      40       90       30       90
# Diglett     50   Ground    NaN    265   10      55       25       35       45
# Shedinja   292      Bug  Ghost    236    1      90       45       30       30
#
#            Speed  Generation  Legendary
# Name
# Blissey       55           2      False
# Chansey       50           1      False
# Wobbuffet     33           2      False
# Wailord       60           3      False
# Alomomola     65           5      False
# ...          ...         ...        ...
# Magikarp      80           1      False
# Feebas        80           3      False
# Duskull       25           3      False
# Diglett       95           1      False
# Shedinja      40           3      False
#
# [800 rows x 12 columns]

# %% [markdown]
# ## Cleaning out missing or corrupted data
#
# - We will consider missing/corrupt data as NaN values
# - We have two apporaches:
#     1. Replace them with some other value
#     2. Throw them away

# %%
mask = np.zeros(pokemon_df.shape, dtype=bool)
mask[30:35, 3:5] = True
pokemon_df[mask] = np.nan
pokemon_df.iloc[25:36]
# Out:
#             #    Type 1  Type 2  Total    HP  Attack  Defense  Sp. Atk  \
# Name
# Raticate   20    Normal     NaN  413.0  55.0      81       60       50
# Spearow    21    Normal  Flying  262.0  40.0      60       30       31
# Fearow     22    Normal  Flying  442.0  65.0      90       65       61
# Ekans      23    Poison     NaN  288.0  35.0      60       44       40
# Arbok      24    Poison     NaN  438.0  60.0      85       69       65
# Pikachu    25  Electric     NaN    NaN   NaN      55       40       50
# Raichu     26  Electric     NaN    NaN   NaN      90       55       90
# Sandshrew  27    Ground     NaN    NaN   NaN      75       85       20
# Sandslash  28    Ground     NaN    NaN   NaN     100      110       45
# Nidoran♀   29    Poison     NaN    NaN   NaN      47       52       40
# Nidorina   30    Poison     NaN  365.0  70.0      62       67       55
#
#            Sp. Def  Speed  Generation  Legendary
# Name
# Raticate        70     97           1      False
# Spearow         31     70           1      False
# Fearow          61    100           1      False
# Ekans           54     55           1      False
# Arbok           79     80           1      False
# Pikachu         50     90           1      False
# Raichu          80    110           1      False
# Sandshrew       30     40           1      False
# Sandslash       55     65           1      False
# Nidoran♀        40     41           1      False
# Nidorina        55     56           1      False

# %%
pokemon_df.loc['Pikachu']
# Out:
# #                   25
# Type 1        Electric
# Type 2             NaN
# Total              NaN
# HP                 NaN
# Attack              55
# Defense             40
# Sp. Atk             50
# Sp. Def             50
# Speed               90
# Generation           1
# Legendary        False
# Name: Pikachu, dtype: object

# %%
df = pokemon_df.dropna()
df.iloc[25:36]
# Out:
#              # Type 1    Type 2  Total    HP  Attack  Defense  Sp. Atk  \
# Name
# Gloom       44  Grass    Poison  395.0  60.0      65       70       85
# Vileplume   45  Grass    Poison  490.0  75.0      80       85      110
# Paras       46    Bug     Grass  285.0  35.0      70       55       45
# Parasect    47    Bug     Grass  405.0  60.0      95       80       60
# Venonat     48    Bug    Poison  305.0  60.0      55       50       40
# Venomoth    49    Bug    Poison  450.0  70.0      65       60       90
# Poliwrath   62  Water  Fighting  510.0  90.0      95       95       70
# Bellsprout  69  Grass    Poison  300.0  50.0      75       35       70
# Weepinbell  70  Grass    Poison  390.0  65.0      90       50       85
# Victreebel  71  Grass    Poison  490.0  80.0     105       65      100
# Tentacool   72  Water    Poison  335.0  40.0      40       35       50
#
#             Sp. Def  Speed  Generation  Legendary
# Name
# Gloom            75     40           1      False
# Vileplume        90     50           1      False
# Paras            55     25           1      False
# Parasect         80     30           1      False
# Venonat          55     45           1      False
# Venomoth         75     90           1      False
# Poliwrath        90     70           1      False
# Bellsprout       30     40           1      False
# Weepinbell       45     55           1      False
# Victreebel       70     70           1      False
# Tentacool       100     70           1      False

# %%
df = pokemon_df.fillna(0)
df.iloc[25:36]
# Out:
#             #    Type 1  Type 2  Total    HP  Attack  Defense  Sp. Atk  \
# Name
# Raticate   20    Normal       0  413.0  55.0      81       60       50
# Spearow    21    Normal  Flying  262.0  40.0      60       30       31
# Fearow     22    Normal  Flying  442.0  65.0      90       65       61
# Ekans      23    Poison       0  288.0  35.0      60       44       40
# Arbok      24    Poison       0  438.0  60.0      85       69       65
# Pikachu    25  Electric       0    0.0   0.0      55       40       50
# Raichu     26  Electric       0    0.0   0.0      90       55       90
# Sandshrew  27    Ground       0    0.0   0.0      75       85       20
# Sandslash  28    Ground       0    0.0   0.0     100      110       45
# Nidoran♀   29    Poison       0    0.0   0.0      47       52       40
# Nidorina   30    Poison       0  365.0  70.0      62       67       55
#
#            Sp. Def  Speed  Generation  Legendary
# Name
# Raticate        70     97           1      False
# Spearow         31     70           1      False
# Fearow          61    100           1      False
# Ekans           54     55           1      False
# Arbok           79     80           1      False
# Pikachu         50     90           1      False
# Raichu          80    110           1      False
# Sandshrew       30     40           1      False
# Sandslash       55     65           1      False
# Nidoran♀        40     41           1      False
# Nidorina        55     56           1      False

# %% [markdown]
# ## pd.Eval
# Is a way to compute an expression on your dataframe automatically and can be very useful. The expression has to be written in a pythonic way.

# %%
pd.eval?

# %%
df = pd.DataFrame({
    'Algorithm': ['XGBoost', 'DNN', 'Perceptron'],
    'MSE': [63.3234, 51.8182, 78.231],
    'Cost': [12, 38, 8]
})
df
# Out:
#     Algorithm      MSE  Cost
# 0     XGBoost  63.3234    12
# 1         DNN  51.8182    38
# 2  Perceptron  78.2310     8

# %%
df = pd.eval('RMSE = df.MSE ** 0.5', target=df)
df
# Out:
#     Algorithm      MSE  Cost      RMSE
# 0     XGBoost  63.3234    12  7.957600
# 1         DNN  51.8182    38  7.198486
# 2  Perceptron  78.2310     8  8.844829

# %% [markdown]
# ## inplace=True
#
# We explicitly have to tell pandas make changes to our dataframe, otherwise it will just return a new df and keep the original intact

# %%
df = df.set_index('Algorithm')
# Out:
#                 MSE  Cost
# Algorithm
# XGBoost     63.3234    12
# DNN         51.8182    38
# Perceptron  78.2310     8

# %% [markdown]
# ## df.query
#
# Like pd.eval we can use df.query to query in a pythonic way

# %%
df.query('MSE > 50 and Cost > 10')
# Out:
#                MSE  Cost
# Algorithm
# XGBoost    63.3234    12
# DNN        51.8182    38
