# %% [markdown]
# # Last time we saw how we could read information from different files (.txt and .jpg)
# # Today we will start with an easier way of handling paths: namely, pathlib!

# %%
# The way I have shown this to you before is with strings specifying the paths:

path_to_file_str = "files/COVID-00003b.jpg"
path_to_file_str.split("/")[1]

# But the longer path we have, the more complicated it becomes to reference different parts of the path!
# reading path.split("/")[5] from a path = "C/home/docs/super-secret/text-files/folder-1/subfolder-5/text-file-1.txt"
# is.. hard
# Out:
# 'COVID-00003.jpg'

# %%
# So now, we are introducing the pathlib!
# Pathlib makes it easier for us to handle long paths in an efficient way,
# and it is neat to read

from pathlib import Path

path_to_file = Path("files/COVID-00003b.jpg")
print(path_to_file.parent)
print(path_to_file.name)
# Out:
# files
# COVID-00003b.jpg

# %%
# with pathlib it is easy to create new paths from old paths:
# maybe i would like to insert another folder to put the file

new_path_to_file = path_to_file.parent / "unchanged_files" / path_to_file.name
print(new_path_to_file)

# if I would do the same using strings, it looks like this:
new_path_to_file = path_to_file_str.split("/")[0] + "\\unchanged_files\\" + path_to_file_str.split("/")[1]
print(new_path_to_file)
# which is a lot less intuitive for someone coming into the code at a later stage!
# Out:
# files\unchanged_files\COVID-00003.jpg
# files\unchanged_files\COVID-00003.jpg

# %% [markdown]
# ## The final thing with pathlib is that it is OS independent - it converts paths between OSX and Windows
#
# ### Working with relative paths in a project that should be able to be run both on OSX and windows can create problems when using strings, as slashes are used differently. Pathlib fixes that for us!
#
# Read more here: https://docs.python.org/3/library/pathlib.html

# %% [markdown]
# # Now we move on to the library called shutil, which is nice to have when we want to move files around and don't care specifically about the file contents
# # i.e. we want to move file A from place B to place C, but we do not need to read the contents of file A

# %%
import shutil

path_to_file = Path("files/COVID-00003b.jpg")
new_path_to_file = path_to_file.parent / "unchanged_files" / path_to_file.name

# %%
path_to_file
# Out:
# WindowsPath('files/COVID-00003b.jpg')

# %%
# Now we have defined the path to the file and what we wish to be the new path
# We can choose if we would like to move the file or copy it!

shutil.copy(path_to_file, new_path_to_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-d0690b6f8079> in <module>
#       2 # We can choose if we would like to move the file or copy it!
#       3
# ----> 4 shutil.copy(path_to_file, new_path_to_file)
#
# ~\anaconda3\envs\ec-python-course\lib\shutil.py in copy(src, dst, follow_symlinks)
#     416     if os.path.isdir(dst):
#     417         dst = os.path.join(dst, os.path.basename(src))
# --> 418     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     419     copymode(src, dst, follow_symlinks=follow_symlinks)
#     420     return dst
#
# ~\anaconda3\envs\ec-python-course\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     262         os.symlink(os.readlink(src), dst)
#     263     else:
# --> 264         with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     265             # macOS
#     266             if _HAS_FCOPYFILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'files\\unchanged_files\\COVID-00003b.jpg'

# %%
# Hmm that did not work because the folder unchanged_files does not exist yet
# so we should change our code to something like this:

try:
    shutil.copy(path_to_file, new_path_to_file)
except FileNotFoundError:
    if not new_path_to_file.exists(): #<----- if the new path does not exist
        new_path_to_file.mkdir(parents=True) #<-- create the new path!
        shutil.copy(path_to_file, new_path_to_file) # <--- and then copy the file

# %% [markdown]
# # Now, we will look at one more nice thing, that can improve file management for us:
# # f-strings

# %% [markdown]
# ## F-strings are present from python 3 and onwards, meaning that if you know
# ## that you are working with a project that should be backwards compatible, maybe this is not the best
# ## otherwise: go ahead!

# %%
# when we are working with strings where we want to modify only parts of it, 
# a neat way of making that readable is by using f-strings!

# let's start with a simple example where we want to create lots of files and
# name them using an index at the end.

for i in range(10):
    file_name = f"covid_0{i}.txt"
    print(file_name)
# Out:
# covid_00.txt
# covid_01.txt
# covid_02.txt
# covid_03.txt
# covid_04.txt
# covid_05.txt
# covid_06.txt
# covid_07.txt
# covid_08.txt
# covid_09.txt

# %%
sample_dataset_path = Path("../exercises/sample_dataset") #<-- this is a RELATIVE path
i = 0
for old_path in sample_dataset_path.glob("*/*"): #<-- the stars means wildcard: any file
    print(old_path)
    new_path = old_path.parents[2] / "cleaned_dataset" / "train" / old_path.parent.name / (f"covid_{i}" + old_path.suffix)
    print(new_path)
    i += 1
    try:
        shutil.copy(old_path, new_path)
    except FileNotFoundError:
        if not new_path.exists():
            new_path.mkdir(parents=True)
            shutil.copy(old_path, new_path)
# Out:
# ..\exercises\sample_dataset\Covid\01.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_0.jpeg
# ..\exercises\sample_dataset\Covid\010.png
# ..\exercises\cleaned_dataset\train\Covid\covid_1.png
# ..\exercises\sample_dataset\Covid\0100.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_2.jpeg
# ..\exercises\sample_dataset\Covid\0102.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_3.jpeg
# ..\exercises\sample_dataset\Covid\0105.png
# ..\exercises\cleaned_dataset\train\Covid\covid_4.png
# ..\exercises\sample_dataset\Covid\0106.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_5.jpeg
# ..\exercises\sample_dataset\Covid\0108.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_6.jpeg
# ..\exercises\sample_dataset\Covid\0111.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_7.jpg
# ..\exercises\sample_dataset\Covid\0112.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_8.jpg
# ..\exercises\sample_dataset\Covid\0113.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_9.jpg
# ..\exercises\sample_dataset\Covid\0115.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_10.jpeg
# ..\exercises\sample_dataset\Covid\0118.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_11.jpeg
# ..\exercises\sample_dataset\Covid\0119.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_12.jpeg
# ..\exercises\sample_dataset\Covid\012.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_13.jpeg
# ..\exercises\sample_dataset\Covid\0120.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_14.jpg
# ..\exercises\sample_dataset\Covid\015.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_15.jpg
# ..\exercises\sample_dataset\Covid\019.png
# ..\exercises\cleaned_dataset\train\Covid\covid_16.png
# ..\exercises\sample_dataset\Covid\02.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_17.jpeg
# ..\exercises\sample_dataset\Covid\020.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_18.jpg
# ..\exercises\sample_dataset\Covid\021.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_19.jpeg
# ..\exercises\sample_dataset\Covid\022.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_20.jpeg
# ..\exercises\sample_dataset\Covid\024.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_21.jpeg
# ..\exercises\sample_dataset\Covid\025.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_22.jpeg
# ..\exercises\sample_dataset\Covid\026.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_23.jpeg
# ..\exercises\sample_dataset\Covid\027.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_24.jpeg
# ..\exercises\sample_dataset\Covid\03.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_25.jpeg
# ..\exercises\sample_dataset\Covid\031.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_26.jpeg
# ..\exercises\sample_dataset\Covid\032.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_27.jpeg
# ..\exercises\sample_dataset\Covid\033.png
# ..\exercises\cleaned_dataset\train\Covid\covid_28.png
# ..\exercises\sample_dataset\Covid\039.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_29.jpeg
# ..\exercises\sample_dataset\Covid\04.png
# ..\exercises\cleaned_dataset\train\Covid\covid_30.png
# ..\exercises\sample_dataset\Covid\040.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_31.jpeg
# ..\exercises\sample_dataset\Covid\041.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_32.jpeg
# ..\exercises\sample_dataset\Covid\042.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_33.jpeg
# ..\exercises\sample_dataset\Covid\043.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_34.jpeg
# ..\exercises\sample_dataset\Covid\044.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_35.jpeg
# ..\exercises\sample_dataset\Covid\045.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_36.jpeg
# ..\exercises\sample_dataset\Covid\046.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_37.jpeg
# ..\exercises\sample_dataset\Covid\047.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_38.jpeg
# ..\exercises\sample_dataset\Covid\048.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_39.jpeg
# ..\exercises\sample_dataset\Covid\049.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_40.jpeg
# ..\exercises\sample_dataset\Covid\050.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_41.jpeg
# ..\exercises\sample_dataset\Covid\051.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_42.jpeg
# ..\exercises\sample_dataset\Covid\052.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_43.jpeg
# ..\exercises\sample_dataset\Covid\053.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_44.jpeg
# ..\exercises\sample_dataset\Covid\054.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_45.jpeg
# ..\exercises\sample_dataset\Covid\055.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_46.jpeg
# ..\exercises\sample_dataset\Covid\056.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_47.jpg
# ..\exercises\sample_dataset\Covid\057.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_48.jpeg
# ..\exercises\sample_dataset\Covid\058.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_49.jpeg
# ..\exercises\sample_dataset\Covid\059.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_50.jpeg
# ..\exercises\sample_dataset\Covid\06.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_51.jpeg
# ..\exercises\sample_dataset\Covid\060.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_52.jpeg
# ..\exercises\sample_dataset\Covid\061.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_53.jpg
# ..\exercises\sample_dataset\Covid\062.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_54.jpeg
# ..\exercises\sample_dataset\Covid\064.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_55.jpg
# ..\exercises\sample_dataset\Covid\065.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_56.jpeg
# ..\exercises\sample_dataset\Covid\067.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_57.jpg
# ..\exercises\sample_dataset\Covid\068.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_58.jpg
# ..\exercises\sample_dataset\Covid\069.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_59.jpg
# ..\exercises\sample_dataset\Covid\07.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_60.jpg
# ..\exercises\sample_dataset\Covid\071.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_61.jpg
# ..\exercises\sample_dataset\Covid\072.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_62.jpeg
# ..\exercises\sample_dataset\Covid\073.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_63.jpg
# ..\exercises\sample_dataset\Covid\074.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_64.jpg
# ..\exercises\sample_dataset\Covid\076.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_65.jpg
# ..\exercises\sample_dataset\Covid\078.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_66.jpeg
# ..\exercises\sample_dataset\Covid\079.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_67.jpeg
# ..\exercises\sample_dataset\Covid\08.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_68.jpeg
# ..\exercises\sample_dataset\Covid\080.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_69.jpg
# ..\exercises\sample_dataset\Covid\081.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_70.jpeg
# ..\exercises\sample_dataset\Covid\082.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_71.jpg
# ..\exercises\sample_dataset\Covid\083.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_72.jpeg
# ..\exercises\sample_dataset\Covid\084.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_73.jpeg
# ..\exercises\sample_dataset\Covid\085.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_74.jpeg
# ..\exercises\sample_dataset\Covid\086.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_75.jpg
# ..\exercises\sample_dataset\Covid\088.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_76.jpeg
# ..\exercises\sample_dataset\Covid\089.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_77.jpg
# ..\exercises\sample_dataset\Covid\09.png
# ..\exercises\cleaned_dataset\train\Covid\covid_78.png
# ..\exercises\sample_dataset\Covid\090.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_79.jpeg
# ..\exercises\sample_dataset\Covid\091.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_80.jpg
# ..\exercises\sample_dataset\Covid\092.png
# ..\exercises\cleaned_dataset\train\Covid\covid_81.png
# ..\exercises\sample_dataset\Covid\094.png
# ..\exercises\cleaned_dataset\train\Covid\covid_82.png
# ..\exercises\sample_dataset\Covid\096.png
# ..\exercises\cleaned_dataset\train\Covid\covid_83.png
# ..\exercises\sample_dataset\Covid\098.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_84.jpeg
# ..\exercises\sample_dataset\Covid\auntminnie-2020_01_31_20_24_2322_2020_01_31_x-ray_coronavirus_US.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_85.jpg
# ..\exercises\sample_dataset\Covid\auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_86.jpeg
# ..\exercises\sample_dataset\Covid\auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_87.jpeg
# ..\exercises\sample_dataset\Covid\auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_88.jpeg
# ..\exercises\sample_dataset\Covid\auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# ..\exercises\cleaned_dataset\train\Covid\covid_89.jpeg
# ..\exercises\sample_dataset\Covid\COVID-00001.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_90.jpg
# ..\exercises\sample_dataset\Covid\COVID-00002.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_91.jpg
# ..\exercises\sample_dataset\Covid\COVID-00003a.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_92.jpg
# ..\exercises\sample_dataset\Covid\COVID-00003b.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_93.jpg
# ..\exercises\sample_dataset\Covid\COVID-00004.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_94.jpg
# ..\exercises\sample_dataset\Covid\COVID-00005.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_95.jpg
# ..\exercises\sample_dataset\Covid\COVID-00006.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_96.jpg
# ..\exercises\sample_dataset\Covid\COVID-00007.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_97.jpg
# ..\exercises\sample_dataset\Covid\COVID-00008.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_98.jpg
# ..\exercises\sample_dataset\Covid\COVID-00009.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_99.jpg
# ..\exercises\sample_dataset\Covid\COVID-00010.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_100.jpg
# ..\exercises\sample_dataset\Covid\COVID-00011.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_101.jpg
# ..\exercises\sample_dataset\Covid\COVID-00012.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_102.jpg
# ..\exercises\sample_dataset\Covid\COVID-00013a.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_103.jpg
# ..\exercises\sample_dataset\Covid\COVID-00013b.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_104.jpg
# ..\exercises\sample_dataset\Covid\COVID-00014.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_105.jpg
# ..\exercises\sample_dataset\Covid\COVID-00015a.png
# ..\exercises\cleaned_dataset\train\Covid\covid_106.png
# ..\exercises\sample_dataset\Covid\COVID-00015b.png
# ..\exercises\cleaned_dataset\train\Covid\covid_107.png
# ..\exercises\sample_dataset\Covid\COVID-00016.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_108.jpg
# ..\exercises\sample_dataset\Covid\COVID-00017.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_109.jpg
# ..\exercises\sample_dataset\Covid\COVID-00018.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_110.jpg
# ..\exercises\sample_dataset\Covid\COVID-00019.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_111.jpg
# ..\exercises\sample_dataset\Covid\COVID-00020.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_112.jpg
# ..\exercises\sample_dataset\Covid\COVID-00021.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_113.jpg
# ..\exercises\sample_dataset\Covid\COVID-00022.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_114.jpg
# ..\exercises\sample_dataset\Covid\COVID-00023.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_115.jpg
# ..\exercises\sample_dataset\Covid\COVID-00024.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_116.jpg
# ..\exercises\sample_dataset\Covid\COVID-00025.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_117.jpg
# ..\exercises\sample_dataset\Covid\COVID-00026.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_118.jpg
# ..\exercises\sample_dataset\Covid\COVID-00027.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_119.jpg
# ..\exercises\sample_dataset\Covid\COVID-00028.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_120.jpg
# ..\exercises\sample_dataset\Covid\COVID-00029.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_121.jpg
# ..\exercises\sample_dataset\Covid\COVID-00030.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_122.jpg
# ..\exercises\sample_dataset\Covid\COVID-00031.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_123.jpg
# ..\exercises\sample_dataset\Covid\COVID-00032.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_124.jpg
# ..\exercises\sample_dataset\Covid\COVID-00033.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_125.jpg
# ..\exercises\sample_dataset\Covid\COVID-00034.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_126.jpg
# ..\exercises\sample_dataset\Covid\COVID-00035.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_127.jpg
# ..\exercises\sample_dataset\Covid\COVID-00036.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_128.jpg
# ..\exercises\sample_dataset\Covid\COVID-00037.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_129.jpg
# ..\exercises\sample_dataset\Covid\COVID-00038.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_130.jpg
# ..\exercises\sample_dataset\Covid\radiopaedia-2019-novel-coronavirus-infected-pneumonia.jpg
# ..\exercises\cleaned_dataset\train\Covid\covid_131.jpg
# ..\exercises\sample_dataset\Normal\01.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_132.jpeg
# ..\exercises\sample_dataset\Normal\010.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_133.jpeg
# ..\exercises\sample_dataset\Normal\0101.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_134.jpeg
# ..\exercises\sample_dataset\Normal\0102.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_135.jpeg
# ..\exercises\sample_dataset\Normal\0103.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_136.jpeg
# ..\exercises\sample_dataset\Normal\0105.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_137.jpeg
# ..\exercises\sample_dataset\Normal\0106.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_138.jpeg
# ..\exercises\sample_dataset\Normal\0107.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_139.jpeg
# ..\exercises\sample_dataset\Normal\0108.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_140.jpeg
# ..\exercises\sample_dataset\Normal\0109.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_141.jpeg
# ..\exercises\sample_dataset\Normal\011.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_142.jpeg
# ..\exercises\sample_dataset\Normal\0110.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_143.jpeg
# ..\exercises\sample_dataset\Normal\0111.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_144.jpeg
# ..\exercises\sample_dataset\Normal\0112.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_145.jpeg
# ..\exercises\sample_dataset\Normal\0114.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_146.jpeg
# ..\exercises\sample_dataset\Normal\0115.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_147.jpeg
# ..\exercises\sample_dataset\Normal\0116.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_148.jpeg
# ..\exercises\sample_dataset\Normal\0117.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_149.jpeg
# ..\exercises\sample_dataset\Normal\0118.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_150.jpeg
# ..\exercises\sample_dataset\Normal\0119.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_151.jpeg
# ..\exercises\sample_dataset\Normal\012.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_152.jpeg
# ..\exercises\sample_dataset\Normal\0120.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_153.jpeg
# ..\exercises\sample_dataset\Normal\0121.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_154.jpeg
# ..\exercises\sample_dataset\Normal\0122.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_155.jpeg
# ..\exercises\sample_dataset\Normal\013.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_156.jpeg
# ..\exercises\sample_dataset\Normal\014.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_157.jpeg
# ..\exercises\sample_dataset\Normal\015.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_158.jpeg
# ..\exercises\sample_dataset\Normal\016.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_159.jpeg
# ..\exercises\sample_dataset\Normal\017.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_160.jpeg
# ..\exercises\sample_dataset\Normal\018.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_161.jpeg
# ..\exercises\sample_dataset\Normal\019.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_162.jpeg
# ..\exercises\sample_dataset\Normal\02.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_163.jpeg
# ..\exercises\sample_dataset\Normal\020.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_164.jpeg
# ..\exercises\sample_dataset\Normal\021.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_165.jpeg
# ..\exercises\sample_dataset\Normal\022.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_166.jpeg
# ..\exercises\sample_dataset\Normal\023.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_167.jpeg
# ..\exercises\sample_dataset\Normal\024.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_168.jpeg
# ..\exercises\sample_dataset\Normal\025.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_169.jpeg
# ..\exercises\sample_dataset\Normal\03.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_170.jpeg
# ..\exercises\sample_dataset\Normal\04.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_171.jpeg
# ..\exercises\sample_dataset\Normal\05.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_172.jpeg
# ..\exercises\sample_dataset\Normal\050.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_173.jpeg
# ..\exercises\sample_dataset\Normal\051.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_174.jpeg
# ..\exercises\sample_dataset\Normal\052.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_175.jpeg
# ..\exercises\sample_dataset\Normal\053.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_176.jpeg
# ..\exercises\sample_dataset\Normal\054.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_177.jpeg
# ..\exercises\sample_dataset\Normal\055.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_178.jpeg
# ..\exercises\sample_dataset\Normal\056.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_179.jpeg
# ..\exercises\sample_dataset\Normal\057.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_180.jpeg
# ..\exercises\sample_dataset\Normal\058.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_181.jpeg
# ..\exercises\sample_dataset\Normal\059.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_182.jpeg
# ..\exercises\sample_dataset\Normal\06.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_183.jpeg
# ..\exercises\sample_dataset\Normal\060.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_184.jpeg
# ..\exercises\sample_dataset\Normal\061.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_185.jpeg
# ..\exercises\sample_dataset\Normal\062.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_186.jpeg
# ..\exercises\sample_dataset\Normal\063.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_187.jpeg
# ..\exercises\sample_dataset\Normal\064.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_188.jpeg
# ..\exercises\sample_dataset\Normal\065.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_189.jpeg
# ..\exercises\sample_dataset\Normal\066.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_190.jpeg
# ..\exercises\sample_dataset\Normal\067.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_191.jpeg
# ..\exercises\sample_dataset\Normal\068.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_192.jpeg
# ..\exercises\sample_dataset\Normal\069.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_193.jpeg
# ..\exercises\sample_dataset\Normal\07.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_194.jpeg
# ..\exercises\sample_dataset\Normal\070.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_195.jpeg
# ..\exercises\sample_dataset\Normal\071.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_196.jpeg
# ..\exercises\sample_dataset\Normal\072.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_197.jpeg
# ..\exercises\sample_dataset\Normal\073.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_198.jpeg
# ..\exercises\sample_dataset\Normal\074.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_199.jpeg
# ..\exercises\sample_dataset\Normal\075.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_200.jpeg
# ..\exercises\sample_dataset\Normal\076.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_201.jpeg
# ..\exercises\sample_dataset\Normal\077.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_202.jpeg
# ..\exercises\sample_dataset\Normal\079.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_203.jpeg
# ..\exercises\sample_dataset\Normal\08.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_204.jpeg
# ..\exercises\sample_dataset\Normal\080.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_205.jpeg
# ..\exercises\sample_dataset\Normal\081.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_206.jpeg
# ..\exercises\sample_dataset\Normal\082.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_207.jpeg
# ..\exercises\sample_dataset\Normal\083.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_208.jpeg
# ..\exercises\sample_dataset\Normal\084.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_209.jpeg
# ..\exercises\sample_dataset\Normal\085.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_210.jpeg
# ..\exercises\sample_dataset\Normal\086.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_211.jpeg
# ..\exercises\sample_dataset\Normal\087.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_212.jpeg
# ..\exercises\sample_dataset\Normal\088.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_213.jpeg
# ..\exercises\sample_dataset\Normal\09.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_214.jpeg
# ..\exercises\sample_dataset\Normal\091.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_215.jpeg
# ..\exercises\sample_dataset\Normal\092.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_216.jpeg
# ..\exercises\sample_dataset\Normal\093.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_217.jpeg
# ..\exercises\sample_dataset\Normal\094.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_218.jpeg
# ..\exercises\sample_dataset\Normal\095.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_219.jpeg
# ..\exercises\sample_dataset\Normal\096.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_220.jpeg
# ..\exercises\sample_dataset\Normal\097.jpeg
# ..\exercises\cleaned_dataset\train\Normal\covid_221.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\01.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_222.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\010.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_223.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0101.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_224.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0102.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_225.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0103.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_226.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0104.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_227.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0105.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_228.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0106.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_229.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0107.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_230.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0108.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_231.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0109.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_232.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\011.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_233.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0110.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_234.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0111.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_235.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0112.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_236.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0113.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_237.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0114.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_238.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0115.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_239.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0116.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_240.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0117.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_241.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0118.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_242.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0119.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_243.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\012.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_244.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\0120.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_245.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\013.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_246.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\016.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_247.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\018.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_248.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\019.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_249.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\02.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_250.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\020.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_251.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\021.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_252.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\022.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_253.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\023.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_254.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\024.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_255.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\025.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_256.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\027.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_257.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\03.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_258.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\031.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_259.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\032.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_260.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\033.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_261.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\034.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_262.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\035.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_263.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\036.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_264.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\037.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_265.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\038.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_266.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\04.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_267.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\041.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_268.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\042.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_269.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\043.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_270.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\044.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_271.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\045.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_272.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\046.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_273.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\047.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_274.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\048.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_275.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\05.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_276.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\051.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_277.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\052.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_278.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\053.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_279.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\054.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_280.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\055.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_281.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\056.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_282.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\057.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_283.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\058.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_284.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\06.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_285.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\061.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_286.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\062.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_287.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\063.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_288.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\064.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_289.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\065.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_290.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\066.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_291.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\067.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_292.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\068.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_293.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\07.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_294.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\071.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_295.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\072.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_296.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\073.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_297.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\074.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_298.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\075.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_299.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\076.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_300.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\077.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_301.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\078.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_302.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\08.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_303.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\081.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_304.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\082.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_305.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\083.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_306.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\084.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_307.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\09.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_308.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\094.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_309.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\095.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_310.jpeg
# ..\exercises\sample_dataset\Viral Pneumonia\096.jpeg
# ..\exercises\cleaned_dataset\train\Viral Pneumonia\covid_311.jpeg
